# %%
import pacal as pc
import matplotlib as plt

# %matplotlib inline

# %%
x = pc.BetaDistr(alpha=2, beta=5)
y = pc.BetaDistr(alpha=10, beta=2)

# %%
z = x + y
z.plot()

# %%
zcdf = z.get_piecewise_cdf_interp()
zcdf.plot()

# %%
z.quantile(0.6)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-9a5f3390e272> in <module>()
# ----> 1 z.quantile(0.6)
#
# C:\Anaconda\lib\site-packages\pacal\distr.pyc in quantile(self, y)
#     213         """The quantile function - inverse cumulative distribution
#     214         function."""
# --> 215         return self.get_piecewise_cdf().inverse(y)
#     216     def ci(self, p = 0.05):
#     217         """Confidence interval.
#
# C:\Anaconda\lib\site-packages\pacal\segments.pyc in inverse(self, y)
#    1719                         x = findinv(segi.f, a = segi.a, b = segi.findRightEps(), c = y, rtol = params.segments.cumint.reltol, maxiter = params.segments.cumint.maxiter)
#    1720                     else:
# ...
